# %%
import pandas as pd
import os

# %%
os.listdir()
# Out:
# ['embeddings_meds.csv',
#  'Medicine_Embeddings_Link_Prediction.ipynb',
#  '.DS_Store',
#  'disease_cause.csv',
#  'medicine_side_effects.csv',
#  'Medicine_Embeddings_Clustering.ipynb',
#  'medicine_uses.csv',
#  'disease_specialty.csv',
#  'embeddigs_diseases.csv',
#  'disease_link_prediction.ipynb',
#  '.ipynb_checkpoints',
#  'application.log',
#  'diseases_embedding.ipynb',
#  'disease_symptoms.csv']

# %%
def func(x):
    x = x.strip()
    x = x.replace('"', '')
    return x

# %%
df1 = pd.read_csv('medicine_uses.csv')
df2 = pd.read_csv('medicine_side_effects.csv')

df1['subject']=df1['subject'].map(func)
df1['predicate']=df1['predicate'].map(func)
df1['object']=df1['object'].map(func)

df2['subject']=df2['subject'].map(func)
df2['predicate']=df2['predicate'].map(func)
df2['object']=df2['object'].map(func)

final_df=pd.concat([df1,df2])

final_df.to_csv('embeddings_meds.csv',index=False)

# %%
final_df['predicate'].unique()
# Out:
# array(['use', 'side_effect'], dtype=object)

# %%
import ampligraph
import numpy as np
from ampligraph.evaluation import train_test_split_no_unseen
from ampligraph.datasets import load_from_csv
import tensorflow as tf
from ampligraph.evaluation import evaluate_performance
from ampligraph.discovery import find_clusters
from sklearn.cluster import KMeans,DBSCAN

# %%
X = load_from_csv('.','embeddings_meds.csv',sep=',')
X=X[1:]
X_train, X_valid = train_test_split_no_unseen(np.array(X), test_size=int(X.shape[0]/10))
from ampligraph.latent_features import ComplEx

model = ComplEx(batches_count=50,
                epochs=300,
                k=100,
                eta=20,
                optimizer='adam', 
                optimizer_params={'lr':1e-4},
                loss='multiclass_nll',
                regularizer='LP', 
                regularizer_params={'p':3, 'lambda':1e-5}, 
                seed=0, 
                verbose=True)

print('Train set size: ', X_train.shape)
print('Test set size: ', X_valid.shape)
# Out:
# Train set size:  (8994, 3)
# Test set size:  (999, 3)

# %%
tf.logging.set_verbosity(tf.logging.ERROR)
model.fit(X_train)
# Out:
# Average Loss:   0.151160: 100%|██████████| 300/300 [04:05<00:00,  1.22epoch/s]

# %%
meds =np.array(list(set(X_train[:,0])))
meds_embeddings = dict(zip(meds, model.get_embeddings(meds)))
len(meds)
# Out:
# 1270

# %%
len(dict(zip(meds,(model.get_embeddings(meds)))))
# Out:
# 1270

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
embeddings_2d = PCA(n_components=2).fit_transform(np.array([i for i in meds_embeddings.values()]))

# %% [markdown]
# ### DBSCAN - Not pre-defining the number of clusters

# %%
clustering_algorithm = DBSCAN()
clusters = find_clusters(meds, model, clustering_algorithm, mode='entity')

# %%
np.unique(clusters)
# Out:
# array([-1,  0,  1,  2,  3])

# %%
plot_df = pd.DataFrame({"meds": meds, 
                        "embedding1": embeddings_2d[:, 0], 
                        "embedding2": embeddings_2d[:, 1],
                        "cluster": "cluster" + pd.Series(clusters).astype(str)})

# %%
def plot_clusters(hue):
    np.random.seed(0)
    plt.figure(figsize=(20, 15))
    plt.title("{} embeddings".format(hue).capitalize())
    ax = sns.scatterplot(data=plot_df[plot_df.meds!="unk"].iloc[0:len(plot_df)], x="embedding1", y="embedding2", hue=hue)
    data=plot_df[plot_df.meds!="unk"].iloc[0:len(plot_df)]
    texts = []
    for i, point in data.iterrows():
        texts.append(plt.text(point['embedding1']+0.02, point['embedding2']+0.01, str(point["meds"])))

# %%
plot_clusters('cluster')

# %%
plot_df=plot_df[plot_df['cluster']!='cluster-1']

# %%
def plot_clusters(hue):
    
    np.random.seed(0)
    plt.figure(figsize=(10, 5))
    plt.title("{} embeddings".format(hue).capitalize())
    d={}
    clusters=['cluster0','cluster1','cluster2','cluster3']
    title =['Imsomnia Medicines','Hypertension Medicine','Diabetes Medicines','Nephrotic Syndrome Medicine']
    for i,c in enumerate(clusters):
        d[c] = title[i]
    
    ax = sns.scatterplot(data=plot_df[plot_df.meds!="unk"].iloc[0:len(plot_df)], x="embedding1", y="embedding2", hue=hue)
    leg_handles = ax.get_legend_handles_labels()[0]
    ax.legend(leg_handles,d.values(), title='Similarity in medicies')
    data=plot_df[plot_df.meds!="unk"].iloc[0:len(plot_df)]
    texts = []

# %%
plot_clusters('cluster')

# %%
#cluster0:hypertension
#cluster1:diabetes/insulin
#cluster2:imsomnia

# %%
hypt=list(plot_df[plot_df['cluster']=='cluster0']['meds'])[:5]
hypt2=list(plot_df[plot_df['cluster']=='cluster1']['meds'])[:5]
hypt3=list(plot_df[plot_df['cluster']=='cluster2']['meds'])[:5]
hypt4=list(plot_df[plot_df['cluster']=='cluster3']['meds'])[:5]

# %%
d=pd.DataFrame({'Imsomnia Medicines':hypt,'Hypertension Medicine':hypt2,'Diabetes Medicines':hypt3,'Nephrotic Syndrome Medicines':hypt4})

# %%
d
# Out:
#   Imsomnia Medicines Hypertension Medicine Diabetes Medicines  \
# 0          estazolam            irbesartan         tolazamide
# 1       glutethimide            zofenopril      rosiglitazone
# 2       butabarbital          guanethidine        Glimepiride
# 3         ethinamate             guanadrel       Troglitazone
# 4       propiomazine            Eplerenone           acarbose
#
#   Nephrotic Syndrome Medicines
# 0                   metolazone
# 1                cyclothiazide
# 2           trichlormethiazide
# 3                   indapamide
# 4           hydroflumethiazide
